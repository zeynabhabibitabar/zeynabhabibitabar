# %% [markdown]
# <a href="https://colab.research.google.com/github/zeynabhabibitabar/zeynabhabibitabar/blob/main/Untitled12.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

df = pd.read_csv("housing.csv")

# %%
df
# Out:
#        longitude  latitude  housing_median_age  total_rooms  total_bedrooms  \
# 0        -122.23     37.88                41.0        880.0           129.0
# 1        -122.22     37.86                21.0       7099.0          1106.0
# 2        -122.24     37.85                52.0       1467.0           190.0
# 3        -122.25     37.85                52.0       1274.0           235.0
# 4        -122.25     37.85                52.0       1627.0           280.0
# ...          ...       ...                 ...          ...             ...
# 20635    -121.09     39.48                25.0       1665.0           374.0
# 20636    -121.21     39.49                18.0        697.0           150.0
# 20637    -121.22     39.43                17.0       2254.0           485.0
# 20638    -121.32     39.43                18.0       1860.0           409.0
# 20639    -121.24     39.37                16.0       2785.0           616.0
#
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 20640 entries, 0 to 20639
# Data columns (total 10 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   longitude           20640 non-null  float64
#  1   latitude            20640 non-null  float64
#  2   housing_median_age  20640 non-null  float64
#  3   total_rooms         20640 non-null  float64
#  4   total_bedrooms      20433 non-null  float64
#  5   population          20640 non-null  float64
#  6   households          20640 non-null  float64
#  7   median_income       20640 non-null  float64
#  8   median_house_value  20640 non-null  float64
#  9   ocean_proximity     20640 non-null  object
# dtypes: float64(9), object(1)
# memory usage: 1.6+ MB

# %%
df.ocean_proximity.value_counts()
# Out:
# <1H OCEAN     9136
# INLAND        6551
# NEAR OCEAN    2658
# NEAR BAY      2290
# ISLAND           5
# Name: ocean_proximity, dtype: int64

# %%
df.describe()
# Out:
#           longitude      latitude  housing_median_age   total_rooms  \
# count  20640.000000  20640.000000        20640.000000  20640.000000
# mean    -119.569704     35.631861           28.639486   2635.763081
# std        2.003532      2.135952           12.585558   2181.615252
# min     -124.350000     32.540000            1.000000      2.000000
# 25%     -121.800000     33.930000           18.000000   1447.750000
# 50%     -118.490000     34.260000           29.000000   2127.000000
# 75%     -118.010000     37.710000           37.000000   3148.000000
# max     -114.310000     41.950000           52.000000  39320.000000
#
#        total_bedrooms    population    households  median_income  \
# count    20433.000000  20640.000000  20640.000000   20640.000000
# mean       537.870553   1425.476744    499.539680       3.870671
# std        421.385070   1132.462122    382.329753       1.899822
# min          1.000000      3.000000      1.000000       0.499900
# ...

# %%
df.hist(bins=100, figsize=(15,9))
# Out:
# array([[<Axes: title={'center': 'longitude'}>,
#         <Axes: title={'center': 'latitude'}>,
#         <Axes: title={'center': 'housing_median_age'}>],
#        [<Axes: title={'center': 'total_rooms'}>,
#         <Axes: title={'center': 'total_bedrooms'}>,
#         <Axes: title={'center': 'population'}>],
#        [<Axes: title={'center': 'households'}>,
#         <Axes: title={'center': 'median_income'}>,
#         <Axes: title={'center': 'median_house_value'}>]], dtype=object)

# %%
df.head()
# Out:
#    longitude  latitude  housing_median_age  total_rooms  total_bedrooms  \
# 0    -122.23     37.88                41.0        880.0           129.0
# 1    -122.22     37.86                21.0       7099.0          1106.0
# 2    -122.24     37.85                52.0       1467.0           190.0
# 3    -122.25     37.85                52.0       1274.0           235.0
# 4    -122.25     37.85                52.0       1627.0           280.0
#
#    population  households  median_income  median_house_value ocean_proximity
# 0       322.0       126.0         8.3252            452600.0        NEAR BAY
# 1      2401.0      1138.0         8.3014            358500.0        NEAR BAY
# 2       496.0       177.0         7.2574            352100.0        NEAR BAY
# 3       558.0       219.0         5.6431            341300.0        NEAR BAY
# 4       565.0       259.0         3.8462            342200.0        NEAR BAY

# %% [markdown]
# #Test set

# %%
len(df)
# Out:
# 20640

# %%
np.random.permutation(len(df))
# Out:
# array([ 3752,  4731,  1277, ..., 17629,  6679,  3333])

# %%
random_indices = np.random.permutation(len(df))
print(random_indices)
# Out:
# [16086  4706 17768 ... 19370   731 15021]

# %%
test_set_size = int(len(df) * 0.2)
print(test_set_size)
# Out:
# 4128

# %%
test_random_indices=random_indices[ :test_set_size]
train_random_indices=random_indices[test_set_size: ]
print(f'test_random_indices = {test_random_indices}')
print(f'train_random_indices = {train_random_indices}')
# Out:
# test_random_indices = [16086  4706 17768 ... 11688  2671    76]
# train_random_indices = [  951  9295 14489 ... 19370   731 15021]

# %%
df.iloc[test_random_indices]
# Out:
#        longitude  latitude  housing_median_age  total_rooms  total_bedrooms  \
# 16086    -122.49     37.73                36.0       1821.0           292.0
# 4706     -118.34     34.06                52.0       1482.0           336.0
# 17768    -121.85     37.35                29.0       3515.0           807.0
# 8089     -118.21     33.81                43.0        905.0           199.0
# 6972     -118.03     33.98                46.0       1974.0           465.0
# ...          ...       ...                 ...          ...             ...
# 18801    -121.83     40.69                14.0        821.0           170.0
# 20374    -118.84     34.16                18.0       6075.0          1056.0
# 11688    -118.00     33.88                18.0       2628.0           720.0
# 2671     -115.73     33.09                27.0        452.0           103.0
# 76       -122.28     37.81                36.0       2914.0           562.0
#
# ...

# %%
df.iloc[train_random_indices]
# Out:
#        longitude  latitude  housing_median_age  total_rooms  total_bedrooms  \
# 951      -121.93     37.71                26.0       4822.0           845.0
# 9295     -122.49     38.00                26.0         48.0             8.0
# 14489    -117.26     32.85                42.0       1761.0           329.0
# 15439    -117.23     33.20                21.0       2284.0           360.0
# 7882     -118.12     33.88                36.0       1083.0           218.0
# ...          ...       ...                 ...          ...             ...
# 8972     -118.41     34.01                44.0       2010.0           394.0
# 2832     -119.01     35.38                36.0        790.0           224.0
# 19370    -123.00     38.33                 8.0       3223.0           637.0
# 731      -122.13     37.68                44.0       2147.0           399.0
# 15021    -117.03     32.79                17.0       7352.0          1699.0
#
# ...

# %%
def shuffle_and_split_df(df, test_ratio):
  random_indices = np.random.permutation(len(df))
  #print(f'random_indices = {random_indices}')
  test_set_size = int(len(df) * test_ratio)
  #print(f'test_set_size = {test_set_size}')
  test_random_indices=random_indices[ :test_set_size]
  train_random_indices=random_indices[test_set_size: ]
  #print(f'test_random_indices = {test_random_indices}')
  #print(f'train_random_indices = {train_random_indices}')
  return df.iloc[test_random_indices], df.iloc[train_random_indices]

# %%
len(test_random_indices)
# Out:
# 4128

# %%
train_set, test_set = shuffle_and_split_df(df, 0.2)

# %%
len(test_set)
# Out:
# 16512

# %%
train_set
# Out:
#        longitude  latitude  housing_median_age  total_rooms  total_bedrooms  \
# 11839    -120.95     39.93                26.0       2023.0           385.0
# 9114     -118.22     34.63                 4.0      14348.0          2145.0
# 5180     -118.26     33.95                44.0       1481.0           329.0
# 1452     -121.97     37.97                24.0       1330.0           183.0
# 13145    -121.51     38.26                52.0        910.0           212.0
# ...          ...       ...                 ...          ...             ...
# 9148     -118.48     34.47                36.0         84.0            12.0
# 2279     -119.78     36.78                31.0       2164.0           456.0
# 3393     -118.31     34.27                35.0       1446.0           274.0
# 18373    -121.86     37.22                18.0       7245.0          1029.0
# 13654    -117.31     34.04                29.0       2481.0           383.0
#
# ...

# %%
test_set
# Out:
#        longitude  latitude  housing_median_age  total_rooms  total_bedrooms  \
# 9697     -121.61     36.69                19.0       9899.0          2617.0
# 15353    -117.31     33.25                13.0       3075.0           630.0
# 10241    -117.88     33.89                17.0       3218.0           923.0
# 5002     -118.32     34.01                52.0       3104.0           645.0
# 6087     -117.88     34.09                29.0       3416.0           790.0
# ...          ...       ...                 ...          ...             ...
# 10234    -117.91     33.86                26.0       2296.0           570.0
# 16158    -122.50     37.77                52.0       2433.0           454.0
# 15385    -116.95     33.31                16.0       2921.0           639.0
# 15512    -117.11     33.19                15.0       3154.0           488.0
# 15654    -122.40     37.79                52.0       1185.0           660.0
#
# ...

# %%
train_set
# Out:
#        longitude  latitude  housing_median_age  total_rooms  total_bedrooms  \
# 11839    -120.95     39.93                26.0       2023.0           385.0
# 9114     -118.22     34.63                 4.0      14348.0          2145.0
# 5180     -118.26     33.95                44.0       1481.0           329.0
# 1452     -121.97     37.97                24.0       1330.0           183.0
# 13145    -121.51     38.26                52.0        910.0           212.0
# ...          ...       ...                 ...          ...             ...
# 9148     -118.48     34.47                36.0         84.0            12.0
# 2279     -119.78     36.78                31.0       2164.0           456.0
# 3393     -118.31     34.27                35.0       1446.0           274.0
# 18373    -121.86     37.22                18.0       7245.0          1029.0
# 13654    -117.31     34.04                29.0       2481.0           383.0
#
# ...

# %%
shuffle_and_split_df(df, 0.2)[0]
# Out:
#        longitude  latitude  housing_median_age  total_rooms  total_bedrooms  \
# 13179    -117.76     33.98                 3.0       9662.0          1385.0
# 465      -122.28     37.86                52.0        938.0           195.0
# 15335    -117.33     33.21                17.0       1246.0           300.0
# 2589     -124.10     40.88                35.0       2987.0           578.0
# 5790     -118.25     34.15                20.0       3960.0          1027.0
# ...          ...       ...                 ...          ...             ...
# 6851     -118.15     34.07                44.0       1626.0           383.0
# 7677     -118.09     33.92                33.0        879.0           181.0
# 14864    -117.09     32.64                38.0       2095.0           536.0
# 12790    -121.45     38.65                 5.0       2680.0           502.0
# 19855    -119.45     36.35                22.0       1824.0           333.0
#
# ...

# %%
shuffle_and_split_df(df, 0.2)[1]
# Out:
#        longitude  latitude  housing_median_age  total_rooms  total_bedrooms  \
# 3773     -118.42     34.17                31.0       2235.0           363.0
# 11648    -118.03     33.86                19.0       1795.0           328.0
# 9955     -122.18     38.35                24.0        407.0            68.0
# 17148    -122.20     37.43                38.0       3626.0           528.0
# 14644    -117.20     32.78                38.0       2662.0           498.0
# ...          ...       ...                 ...          ...             ...
# 15791    -122.42     37.77                52.0        759.0           323.0
# 12901    -121.33     38.62                19.0       1853.0           415.0
# 1612     -122.08     37.87                26.0       2405.0           564.0
# 6338     -117.88     33.96                16.0      19059.0          3079.0
# 13545    -117.31     34.13                38.0       1287.0           284.0
#
# ...

# %%
def shuffle_and_split_df(df, test_ratio):
  np.random.seed(40)
  random_indices = np.random.permutation(len(df))
  test_set_size = int(len(df) * test_ratio)
  test_random_indices = random_indices[:test_set_size]
  train_random_indices = random_indices[test_set_size:]
  return df.iloc[train_random_indices], df.iloc[test_random_indices]

# %%
from zlib import crc32
crc32(np.int64(test_random_indices))
# Out:
# 4039923754

# %%
crc32(b"abc")
# Out:
# 891568578

# %%
def is_identifier_in_test_set(identifier, test_ratio):
  return crc32(np.int64(identifier))< test_ratio*2**32
