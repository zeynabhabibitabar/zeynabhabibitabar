# %% [markdown]
# <a href="https://colab.research.google.com/github/zeynabhabibitabar/zeynabhabibitabar/blob/main/Cleaning_data_and_prepare_data.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

df = pd.read_csv("housing.csv")

# %%
df
# Out:
#        longitude  latitude  housing_median_age  total_rooms  total_bedrooms  \
# 0        -122.23     37.88                41.0        880.0           129.0
# 1        -122.22     37.86                21.0       7099.0          1106.0
# 2        -122.24     37.85                52.0       1467.0           190.0
# 3        -122.25     37.85                52.0       1274.0           235.0
# 4        -122.25     37.85                52.0       1627.0           280.0
# ...          ...       ...                 ...          ...             ...
# 20635    -121.09     39.48                25.0       1665.0           374.0
# 20636    -121.21     39.49                18.0        697.0           150.0
# 20637    -121.22     39.43                17.0       2254.0           485.0
# 20638    -121.32     39.43                18.0       1860.0           409.0
# 20639    -121.24     39.37                16.0       2785.0           616.0
#
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 20640 entries, 0 to 20639
# Data columns (total 10 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   longitude           20640 non-null  float64
#  1   latitude            20640 non-null  float64
#  2   housing_median_age  20640 non-null  float64
#  3   total_rooms         20640 non-null  float64
#  4   total_bedrooms      20433 non-null  float64
#  5   population          20640 non-null  float64
#  6   households          20640 non-null  float64
#  7   median_income       20640 non-null  float64
#  8   median_house_value  20640 non-null  float64
#  9   ocean_proximity     20640 non-null  object
# dtypes: float64(9), object(1)
# memory usage: 1.6+ MB

# %%
df.ocean_proximity.value_counts()
# Out:
# <1H OCEAN     9136
# INLAND        6551
# NEAR OCEAN    2658
# NEAR BAY      2290
# ISLAND           5
# Name: ocean_proximity, dtype: int64

# %%
df.describe()
# Out:
#           longitude      latitude  housing_median_age   total_rooms  \
# count  20640.000000  20640.000000        20640.000000  20640.000000
# mean    -119.569704     35.631861           28.639486   2635.763081
# std        2.003532      2.135952           12.585558   2181.615252
# min     -124.350000     32.540000            1.000000      2.000000
# 25%     -121.800000     33.930000           18.000000   1447.750000
# 50%     -118.490000     34.260000           29.000000   2127.000000
# 75%     -118.010000     37.710000           37.000000   3148.000000
# max     -114.310000     41.950000           52.000000  39320.000000
#
#        total_bedrooms    population    households  median_income  \
# count    20433.000000  20640.000000  20640.000000   20640.000000
# mean       537.870553   1425.476744    499.539680       3.870671
# std        421.385070   1132.462122    382.329753       1.899822
# min          1.000000      3.000000      1.000000       0.499900
# ...

# %%
df.hist(bins=100, figsize=(15,9))
# Out:
# array([[<Axes: title={'center': 'longitude'}>,
#         <Axes: title={'center': 'latitude'}>,
#         <Axes: title={'center': 'housing_median_age'}>],
#        [<Axes: title={'center': 'total_rooms'}>,
#         <Axes: title={'center': 'total_bedrooms'}>,
#         <Axes: title={'center': 'population'}>],
#        [<Axes: title={'center': 'households'}>,
#         <Axes: title={'center': 'median_income'}>,
#         <Axes: title={'center': 'median_house_value'}>]], dtype=object)

# %%
df.head()
# Out:
#    longitude  latitude  housing_median_age  total_rooms  total_bedrooms  \
# 0    -122.23     37.88                41.0        880.0           129.0
# 1    -122.22     37.86                21.0       7099.0          1106.0
# 2    -122.24     37.85                52.0       1467.0           190.0
# 3    -122.25     37.85                52.0       1274.0           235.0
# 4    -122.25     37.85                52.0       1627.0           280.0
#
#    population  households  median_income  median_house_value ocean_proximity
# 0       322.0       126.0         8.3252            452600.0        NEAR BAY
# 1      2401.0      1138.0         8.3014            358500.0        NEAR BAY
# 2       496.0       177.0         7.2574            352100.0        NEAR BAY
# 3       558.0       219.0         5.6431            341300.0        NEAR BAY
# 4       565.0       259.0         3.8462            342200.0        NEAR BAY

# %% [markdown]
# #Train and Test set

# %%
len(df)
# Out:
# 20640

# %%
np.random.permutation(len(df))
# Out:
# array([18745, 11520,  3955, ...,  8723, 16786, 15519])

# %%
random_indices = np.random.permutation(len(df))
print(random_indices)
# Out:
# [ 8915  7987 15853 ...  8132  9609 11170]

# %%
test_set_size = int(len(df) * 0.2)
print(test_set_size)
# Out:
# 4128

# %%
test_random_indices=random_indices[ :test_set_size]
train_random_indices=random_indices[test_set_size: ]
print(f'test_random_indices = {test_random_indices}')
print(f'train_random_indices = {train_random_indices}')
# Out:
# test_random_indices = [ 8915  7987 15853 ...  1719  7397 17964]
# train_random_indices = [ 7761  3227  4082 ...  8132  9609 11170]

# %%
df.iloc[test_random_indices]
# Out:
#        longitude  latitude  housing_median_age  total_rooms  total_bedrooms  \
# 8915     -118.46     34.03                52.0        523.0             NaN
# 7987     -118.17     33.85                39.0       2247.0           526.0
# 15853    -122.43     37.74                52.0       1514.0           314.0
# 1660     -121.94     37.94                26.0       1299.0           174.0
# 12790    -121.45     38.65                 5.0       2680.0           502.0
# ...          ...       ...                 ...          ...             ...
# 18165    -122.02     37.35                17.0       2975.0           608.0
# 1695     -122.27     38.00                15.0       1216.0           166.0
# 1719     -122.33     37.98                 3.0       2850.0           544.0
# 7397     -118.23     33.96                36.0       1062.0           270.0
# 17964    -121.98     37.32                17.0       9789.0          2552.0
#
# ...

# %%
df.iloc[train_random_indices]
# Out:
#        longitude  latitude  housing_median_age  total_rooms  total_bedrooms  \
# 7761     -118.10     33.91                40.0        513.0           100.0
# 3227     -119.64     36.32                32.0       2205.0           523.0
# 4082     -118.38     34.16                42.0       2358.0           546.0
# 13916    -116.15     34.14                18.0       3312.0           705.0
# 16824    -122.49     37.63                31.0       3109.0           621.0
# ...          ...       ...                 ...          ...             ...
# 6979     -118.02     33.97                34.0       1903.0           293.0
# 17523    -121.91     37.33                52.0       2212.0           563.0
# 8132     -118.12     33.83                45.0       1734.0           331.0
# 9609     -120.50     37.30                29.0       1572.0           456.0
# 11170    -117.98     33.82                34.0       1038.0           175.0
#
# ...

# %%
def shuffle_and_split_df(df, test_ratio):
  random_indices = np.random.permutation(len(df))
  #print(f'random_indices = {random_indices}')
  test_set_size = int(len(df) * test_ratio)
  #print(f'test_set_size = {test_set_size}')
  test_random_indices=random_indices[ :test_set_size]
  train_random_indices=random_indices[test_set_size: ]
  #print(f'test_random_indices = {test_random_indices}')
  #print(f'train_random_indices = {train_random_indices}')
  return df.iloc[test_random_indices], df.iloc[train_random_indices]

# %%
len(test_random_indices)
# Out:
# 4128

# %%
train_set, test_set = shuffle_and_split_df(df, 0.2)

# %%
len(test_set)
# Out:
# 16512

# %%
train_set
# Out:
#        longitude  latitude  housing_median_age  total_rooms  total_bedrooms  \
# 16986    -122.26     37.55                17.0       4576.0           814.0
# 18863    -122.21     38.11                35.0       2122.0           400.0
# 4612     -118.29     34.07                22.0        492.0           269.0
# 5764     -118.29     34.17                12.0       2238.0           682.0
# 2014     -119.79     36.72                19.0       1719.0           391.0
# ...          ...       ...                 ...          ...             ...
# 13319    -117.64     34.07                52.0       1644.0           372.0
# 15582    -116.74     33.33                17.0       4190.0           946.0
# 4341     -118.30     34.08                34.0       1562.0           651.0
# 15291    -117.29     33.12                 4.0       1380.0           322.0
# 5576     -118.30     33.84                36.0       1428.0           268.0
#
# ...

# %%
test_set
# Out:
#        longitude  latitude  housing_median_age  total_rooms  total_bedrooms  \
# 12926    -121.30     38.66                28.0       3391.0           550.0
# 17747    -121.74     37.29                 6.0       7292.0          1295.0
# 8630     -118.38     33.88                36.0       2501.0           443.0
# 15244    -117.26     33.00                31.0       2695.0           491.0
# 759      -122.08     37.66                33.0       1547.0           372.0
# ...          ...       ...                 ...          ...             ...
# 7675     -118.09     33.92                36.0        847.0           185.0
# 11562    -117.99     33.75                22.0       3024.0           754.0
# 15680    -122.43     37.80                52.0       1380.0           322.0
# 10101    -117.97     33.92                32.0       2620.0           398.0
# 18111    -122.03     37.30                30.0       3007.0           554.0
#
# ...

# %%
train_set
# Out:
#        longitude  latitude  housing_median_age  total_rooms  total_bedrooms  \
# 16986    -122.26     37.55                17.0       4576.0           814.0
# 18863    -122.21     38.11                35.0       2122.0           400.0
# 4612     -118.29     34.07                22.0        492.0           269.0
# 5764     -118.29     34.17                12.0       2238.0           682.0
# 2014     -119.79     36.72                19.0       1719.0           391.0
# ...          ...       ...                 ...          ...             ...
# 13319    -117.64     34.07                52.0       1644.0           372.0
# 15582    -116.74     33.33                17.0       4190.0           946.0
# 4341     -118.30     34.08                34.0       1562.0           651.0
# 15291    -117.29     33.12                 4.0       1380.0           322.0
# 5576     -118.30     33.84                36.0       1428.0           268.0
#
# ...

# %%
shuffle_and_split_df(df, 0.2)[0]
# Out:
#        longitude  latitude  housing_median_age  total_rooms  total_bedrooms  \
# 12187    -117.31     33.67                 9.0        981.0           169.0
# 16226    -121.32     37.97                46.0       2270.0           427.0
# 14095    -117.10     32.75                11.0       2393.0           726.0
# 365      -122.13     37.75                30.0        414.0            54.0
# 17086    -122.21     37.47                26.0       1777.0           555.0
# ...          ...       ...                 ...          ...             ...
# 18529    -122.03     36.98                37.0       2817.0           716.0
# 12713    -121.38     38.59                36.0       2253.0           434.0
# 13259    -117.68     34.10                11.0       7392.0          1796.0
# 5315     -118.43     34.06                31.0       1317.0           284.0
# 9026     -118.86     34.07                16.0       1409.0           244.0
#
# ...

# %%
shuffle_and_split_df(df, 0.2)[1]
# Out:
#        longitude  latitude  housing_median_age  total_rooms  total_bedrooms  \
# 4146     -118.20     34.13                30.0       3369.0           824.0
# 16608    -120.64     35.65                 9.0       3466.0           673.0
# 14019    -117.16     32.74                21.0       1882.0           486.0
# 6690     -118.08     34.14                52.0       1282.0           189.0
# 6768     -118.14     34.11                52.0       3367.0           545.0
# ...          ...       ...                 ...          ...             ...
# 12892    -121.33     38.66                15.0       4371.0           908.0
# 11494    -118.02     33.71                24.0       2598.0           443.0
# 5890     -118.34     34.15                16.0       1586.0           377.0
# 15432    -117.25     33.20                22.0       2361.0           618.0
# 9438     -119.98     37.43                12.0       2776.0           592.0
#
# ...

# %%
def shuffle_and_split_df(df, test_ratio):
  np.random.seed(40)
  random_indices = np.random.permutation(len(df))
  test_set_size = int(len(df) * test_ratio)
  test_random_indices = random_indices[:test_set_size]
  train_random_indices = random_indices[test_set_size:]
  return df.iloc[train_random_indices], df.iloc[test_random_indices]

# %%
from zlib import crc32
crc32(np.int64(test_random_indices))
# Out:
# 3303722619

# %%
crc32(b"abc")
# Out:
# 891568578

# %% [markdown]
# برای اینکه identifiers ها رو بسازیم و تست کنیم

# %%
def is_identifier_in_test_set(identifier, test_ratio):
  return crc32(np.int64(identifier))< test_ratio*2**32
def split_train_test_with_identifier_hash(df, test_ratio, identifier_column):
  identifiers= df[identifier_column]
  in_test_set= identifiers.apply(lambda id_: is_identifier_in_test_set(id_, test_ratio))
  return df.loc[~in_test_set], df.loc[in_test_set]

# %%
df.reset_index()["index"]
# Out:
# 0            0
# 1            1
# 2            2
# 3            3
# 4            4
#          ...
# 20635    20635
# 20636    20636
# 20637    20637
# 20638    20638
# 20639    20639
# Name: index, Length: 20640, dtype: int64

# %%
train_set, test_set= split_train_test_with_identifier_hash(df.reset_index(), 0.2, "index")

# %%
train_set
# Out:
#        index  longitude  latitude  housing_median_age  total_rooms  \
# 0          0    -122.23     37.88                41.0        880.0
# 1          1    -122.22     37.86                21.0       7099.0
# 3          3    -122.25     37.85                52.0       1274.0
# 4          4    -122.25     37.85                52.0       1627.0
# 6          6    -122.25     37.84                52.0       2535.0
# ...      ...        ...       ...                 ...          ...
# 20635  20635    -121.09     39.48                25.0       1665.0
# 20636  20636    -121.21     39.49                18.0        697.0
# 20637  20637    -121.22     39.43                17.0       2254.0
# 20638  20638    -121.32     39.43                18.0       1860.0
# 20639  20639    -121.24     39.37                16.0       2785.0
#
#        total_bedrooms  population  households  median_income  \
# 0               129.0       322.0       126.0         8.3252
# ...

# %%
test_set
# Out:
#        index  longitude  latitude  housing_median_age  total_rooms  \
# 2          2    -122.24     37.85                52.0       1467.0
# 5          5    -122.25     37.85                52.0        919.0
# 12        12    -122.26     37.85                52.0       2491.0
# 16        16    -122.27     37.85                52.0       1966.0
# 23        23    -122.27     37.84                52.0       1688.0
# ...      ...        ...       ...                 ...          ...
# 20615  20615    -121.54     39.08                23.0       1076.0
# 20617  20617    -121.53     39.06                20.0        561.0
# 20622  20622    -121.44     39.00                20.0        755.0
# 20626  20626    -121.43     39.18                36.0       1124.0
# 20629  20629    -121.39     39.12                28.0      10035.0
#
#        total_bedrooms  population  households  median_income  \
# 2               190.0       496.0       177.0         7.2574
# ...

# %%
df_with_identifier = df
df_with_identifier["identifier"] = df["longitude"]*1000 + df["latitude"] +df["total_rooms"]
df_with_identifier
# Out:
#        longitude  latitude  housing_median_age  total_rooms  total_bedrooms  \
# 0        -122.23     37.88                41.0        880.0           129.0
# 1        -122.22     37.86                21.0       7099.0          1106.0
# 2        -122.24     37.85                52.0       1467.0           190.0
# 3        -122.25     37.85                52.0       1274.0           235.0
# 4        -122.25     37.85                52.0       1627.0           280.0
# ...          ...       ...                 ...          ...             ...
# 20635    -121.09     39.48                25.0       1665.0           374.0
# 20636    -121.21     39.49                18.0        697.0           150.0
# 20637    -121.22     39.43                17.0       2254.0           485.0
# 20638    -121.32     39.43                18.0       1860.0           409.0
# 20639    -121.24     39.37                16.0       2785.0           616.0
#
# ...

# %%
train_set, test_set= split_train_test_with_identifier_hash(df_with_identifier,
                                                           0.2,
                                                           "identifier")

# %%
train_set
# Out:
#        index  longitude  latitude  housing_median_age  total_rooms  \
# 0          0    -122.23     37.88                41.0        880.0
# 1          1    -122.22     37.86                21.0       7099.0
# 3          3    -122.25     37.85                52.0       1274.0
# 4          4    -122.25     37.85                52.0       1627.0
# 6          6    -122.25     37.84                52.0       2535.0
# ...      ...        ...       ...                 ...          ...
# 20635  20635    -121.09     39.48                25.0       1665.0
# 20636  20636    -121.21     39.49                18.0        697.0
# 20637  20637    -121.22     39.43                17.0       2254.0
# 20638  20638    -121.32     39.43                18.0       1860.0
# 20639  20639    -121.24     39.37                16.0       2785.0
#
#        total_bedrooms  population  households  median_income  \
# 0               129.0       322.0       126.0         8.3252
# ...

# %%
test_set
# Out:
#        index  longitude  latitude  housing_median_age  total_rooms  \
# 2          2    -122.24     37.85                52.0       1467.0
# 5          5    -122.25     37.85                52.0        919.0
# 12        12    -122.26     37.85                52.0       2491.0
# 16        16    -122.27     37.85                52.0       1966.0
# 23        23    -122.27     37.84                52.0       1688.0
# ...      ...        ...       ...                 ...          ...
# 20615  20615    -121.54     39.08                23.0       1076.0
# 20617  20617    -121.53     39.06                20.0        561.0
# 20622  20622    -121.44     39.00                20.0        755.0
# 20626  20626    -121.43     39.18                36.0       1124.0
# 20629  20629    -121.39     39.12                28.0      10035.0
#
#        total_bedrooms  population  households  median_income  \
# 2               190.0       496.0       177.0         7.2574
# ...

# %%
from tables.tests.test_suite import test
from sklearn.model_selection import train_test_split
train_set, test_set= train_test_split(df, test_size=0.2, random_state=40)

# %%
train_set
# Out:
#        index  longitude  latitude  housing_median_age  total_rooms  \
# 0          0    -122.23     37.88                41.0        880.0
# 1          1    -122.22     37.86                21.0       7099.0
# 3          3    -122.25     37.85                52.0       1274.0
# 4          4    -122.25     37.85                52.0       1627.0
# 6          6    -122.25     37.84                52.0       2535.0
# ...      ...        ...       ...                 ...          ...
# 20635  20635    -121.09     39.48                25.0       1665.0
# 20636  20636    -121.21     39.49                18.0        697.0
# 20637  20637    -121.22     39.43                17.0       2254.0
# 20638  20638    -121.32     39.43                18.0       1860.0
# 20639  20639    -121.24     39.37                16.0       2785.0
#
#        total_bedrooms  population  households  median_income  \
# 0               129.0       322.0       126.0         8.3252
# ...

# %%
test_set
# Out:
#        longitude  latitude  housing_median_age  total_rooms  total_bedrooms  \
# 6607     -118.14     34.18                47.0       3457.0           622.0
# 884      -121.97     37.54                31.0       1949.0           344.0
# 9457     -123.84     39.83                19.0       1461.0           340.0
# 18681    -121.82     36.86                17.0       1573.0           272.0
# 4654     -118.33     34.05                48.0       2405.0           527.0
# ...          ...       ...                 ...          ...             ...
# 19314    -122.87     38.43                36.0       1987.0           387.0
# 15433    -117.25     33.20                10.0       2050.0           473.0
# 3631     -118.43     34.23                35.0       2049.0           390.0
# 3689     -118.36     34.23                15.0       2485.0           742.0
# 11895    -117.36     33.97                32.0       1625.0           335.0
#
# ...

# %%
pd.cut(df['median_income'],
       bins=[0.0,1.5,3.0,4.5,6.0, np.inf],
       labels=[1,2,3,4,5])
# Out:
# 0        5
# 1        5
# 2        5
# 3        4
# 4        3
#         ..
# 20635    2
# 20636    2
# 20637    2
# 20638    2
# 20639    2
# Name: median_income, Length: 20640, dtype: category
# Categories (5, int64): [1 < 2 < 3 < 4 < 5]

# %%
df["median_income"]
# Out:
# 0        8.3252
# 1        8.3014
# 2        7.2574
# 3        5.6431
# 4        3.8462
#           ...
# 20635    1.5603
# 20636    2.5568
# 20637    1.7000
# 20638    1.8672
# 20639    2.3886
# Name: median_income, Length: 20640, dtype: float64

# %%
df["median_income_categorise"]= pd.cut(df['median_income'],
                                      bins=[0.0,1.5,3.0,4.5,6.0, np.inf],
                                      labels=[1,2,3,4,5])
df
# Out:
#        longitude  latitude  housing_median_age  total_rooms  total_bedrooms  \
# 0        -122.23     37.88                41.0        880.0           129.0
# 1        -122.22     37.86                21.0       7099.0          1106.0
# 2        -122.24     37.85                52.0       1467.0           190.0
# 3        -122.25     37.85                52.0       1274.0           235.0
# 4        -122.25     37.85                52.0       1627.0           280.0
# ...          ...       ...                 ...          ...             ...
# 20635    -121.09     39.48                25.0       1665.0           374.0
# 20636    -121.21     39.49                18.0        697.0           150.0
# 20637    -121.22     39.43                17.0       2254.0           485.0
# 20638    -121.32     39.43                18.0       1860.0           409.0
# 20639    -121.24     39.37                16.0       2785.0           616.0
#
# ...

# %% [markdown]
# برای نمایش طبقه بندی انجام شده از دستور value_count

# %%
df["median_income_categorise"].value_counts()
# Out:
# 3    7236
# 2    6581
# 4    3639
# 5    2362
# 1     822
# Name: median_income_categorise, dtype: int64

# %% [markdown]
# برای رسم ستون جدید از دستور plot

# %%
df["median_income_categorise"].value_counts().plot.bar()
# Out:
# <Axes: >

# %% [markdown]
# برای مرتب سازی ستون ها از دستور sort

# %%
df["median_income_categorise"].value_counts().sort_index().plot.bar()
# Out:
# <Axes: >

# %% [markdown]
# برای نشان دادن جزییات grid=true

# %%
df["median_income_categorise"].value_counts().sort_index().plot.bar(grid=True)
# Out:
# <Axes: >

# %% [markdown]
# با استفاده از کتابخانه sklearn

# %%
from sklearn.model_selection import StratifiedShuffleSplit
sss = StratifiedShuffleSplit(n_splits=10, test_size=0.2, random_state=40)
stratified_split=[]

for train_i, test_i in sss.split(df, df["median_income_categorise"]):
  stratified_train_set_n= df.iloc[train_i]
  stratified_test_set_n= df.iloc[test_i]

  stratified_split.append([stratified_train_set_n,stratified_test_set_n])

# %%
len(stratified_split)
# Out:
# 10

# %%
stratified_split[0]
# Out:
# [       longitude  latitude  housing_median_age  total_rooms  total_bedrooms  \
#  16415    -121.26     37.88                42.0        465.0            93.0
#  1279     -121.64     37.85                22.0       1999.0           415.0
#  7741     -118.15     33.95                35.0       2753.0           702.0
#  4425     -118.24     34.07                27.0        223.0            80.0
#  1283     -121.82     38.02                46.0        176.0            43.0
#  ...          ...       ...                 ...          ...             ...
#  1221     -120.65     38.28                21.0       3095.0           681.0
#  12640    -121.45     38.53                34.0       1893.0           415.0
#  5747     -118.27     34.17                48.0       1560.0           280.0
#  16224    -121.33     37.98                36.0       3113.0           576.0
#  8967     -118.40     34.00                37.0       1534.0           258.0
#
# ...

# %%
stratified_train_set, stratified_test_set = stratified_split[0]

# %%
stratified_train_set
# Out:
#        longitude  latitude  housing_median_age  total_rooms  total_bedrooms  \
# 16415    -121.26     37.88                42.0        465.0            93.0
# 1279     -121.64     37.85                22.0       1999.0           415.0
# 7741     -118.15     33.95                35.0       2753.0           702.0
# 4425     -118.24     34.07                27.0        223.0            80.0
# 1283     -121.82     38.02                46.0        176.0            43.0
# ...          ...       ...                 ...          ...             ...
# 1221     -120.65     38.28                21.0       3095.0           681.0
# 12640    -121.45     38.53                34.0       1893.0           415.0
# 5747     -118.27     34.17                48.0       1560.0           280.0
# 16224    -121.33     37.98                36.0       3113.0           576.0
# 8967     -118.40     34.00                37.0       1534.0           258.0
#
# ...

# %%
stratified_test_set
# Out:
#        longitude  latitude  housing_median_age  total_rooms  total_bedrooms  \
# 5905     -118.42     34.29                34.0       1489.0           326.0
# 4830     -118.30     34.04                37.0       1470.0           399.0
# 10969    -117.87     33.76                37.0       4943.0           851.0
# 7048     -118.05     33.94                34.0        495.0           120.0
# 13721    -117.18     34.07                 7.0       1347.0           301.0
# ...          ...       ...                 ...          ...             ...
# 3377     -118.29     34.25                19.0       1988.0           594.0
# 19816    -119.29     36.54                18.0       2581.0           628.0
# 20545    -121.75     38.55                26.0       4802.0           950.0
# 3330     -122.48     38.90                10.0        304.0            63.0
# 14222    -117.04     32.66                22.0       3362.0           630.0
#
# ...

# %%
stratified_train_set["median_income_categorise"]
# Out:
# 16415    3
# 1279     3
# 7741     2
# 4425     2
# 1283     2
#         ..
# 1221     2
# 12640    2
# 5747     4
# 16224    3
# 8967     4
# Name: median_income_categorise, Length: 16512, dtype: category
# Categories (5, int64): [1 < 2 < 3 < 4 < 5]

# %% [markdown]
# برای نشان دادن درصد هر طبقه

# %%
stratified_train_set["median_income_categorise"].value_counts()/len(stratified_train_set)
# Out:
# 3    0.350594
# 2    0.318859
# 4    0.176296
# 5    0.114462
# 1    0.039789
# Name: median_income_categorise, dtype: float64

# %% [markdown]
# برای نشان دادن نمودار و درصد هر طبقه

# %%
stratified_test_set["median_income_categorise"]
# Out:
# 5905     3
# 4830     2
# 10969    3
# 7048     2
# 13721    2
#         ..
# 3377     2
# 19816    2
# 20545    3
# 3330     2
# 14222    3
# Name: median_income_categorise, Length: 4128, dtype: category
# Categories (5, int64): [1 < 2 < 3 < 4 < 5]

# %% [markdown]
# برای نشان دادن درصد هر طبقه

# %%
stratified_test_set["median_income_categorise"].value_counts()/len(stratified_test_set)
# Out:
# 3    0.350533
# 2    0.318798
# 4    0.176357
# 5    0.114341
# 1    0.039971
# Name: median_income_categorise, dtype: float64

# %% [markdown]
# و در نهایت سریع ترین روش کد train_test_split

# %%
str_train_set, str_test_set = train_test_split(df,
                                               test_size=0.2,
                                               stratify=df["median_income_categorise"]
                                               , random_state=40)

# %%
str_train_set["median_income_categorise"].value_counts()/len(str_train_set)
# Out:
# 3    0.350594
# 2    0.318859
# 4    0.176296
# 5    0.114462
# 1    0.039789
# Name: median_income_categorise, dtype: float64

# %%
str_test_set["median_income_categorise"].value_counts()/len(str_test_set)
# Out:
# 3    0.350533
# 2    0.318798
# 4    0.176357
# 5    0.114341
# 1    0.039971
# Name: median_income_categorise, dtype: float64

# %% [markdown]
# در انتها باید ستون طبقه بندی شده را از روی داده حذف کنیم با دستور drop

# %%
str_train_set = str_train_set.drop("median_income_categorise",axis=1)

# %%
str_test_set = str_test_set.drop("median_income_categorise",axis=1)

# %%
str_test_set
# Out:
#        longitude  latitude  housing_median_age  total_rooms  total_bedrooms  \
# 5905     -118.42     34.29                34.0       1489.0           326.0
# 4830     -118.30     34.04                37.0       1470.0           399.0
# 10969    -117.87     33.76                37.0       4943.0           851.0
# 7048     -118.05     33.94                34.0        495.0           120.0
# 13721    -117.18     34.07                 7.0       1347.0           301.0
# ...          ...       ...                 ...          ...             ...
# 3377     -118.29     34.25                19.0       1988.0           594.0
# 19816    -119.29     36.54                18.0       2581.0           628.0
# 20545    -121.75     38.55                26.0       4802.0           950.0
# 3330     -122.48     38.90                10.0        304.0            63.0
# 14222    -117.04     32.66                22.0       3362.0           630.0
#
# ...

# %% [markdown]
# #visualize

# %%
df["median_income"]
# Out:
# 0        8.3252
# 1        8.3014
# 2        7.2574
# 3        5.6431
# 4        3.8462
#           ...
# 20635    1.5603
# 20636    2.5568
# 20637    1.7000
# 20638    1.8672
# 20639    2.3886
# Name: median_income, Length: 20640, dtype: float64

# %%
train= str_train_set

# %%
sns.scatterplot(data=train, x="longitude", y="latitude")
# Out:
# <Axes: xlabel='longitude', ylabel='latitude'>

# %% [markdown]
# اگر بخواهیم سایز داده ها را متناسب با یکی از فیچرهای
#
# ---
#
# دیگه (مثلا اینجا جمعیت)تغییر بدیم

# %%
sns.scatterplot(data=train,
                x="longitude",
                y="latitude",
                size="population",
                alpha=0.3)
# Out:
# <Axes: xlabel='longitude', ylabel='latitude'>

# %% [markdown]
# گر بخواهیم رنگ داده ها را متناسب با یکی از فیچرهای
#
# ---
#
# دیگه (مثلا اینجا ستون هدف)تغییر بدیم

# %%
sns.scatterplot(data=train,
                x="longitude",
                y="latitude",
                size="population",
                alpha=0.3,
                hue="median_house_value")
# Out:
# <Axes: xlabel='longitude', ylabel='latitude'>

# %% [markdown]
# اگر بخواهیم جدول اطلاعات داخل نمودار به بیرون از آن انتقال داده شود

# %%
ax = sns.scatterplot(data=train,
                      x="longitude",
                      y="latitude",
                      size="population",
                      alpha=0.3,
                      hue="median_house_value")
sns.move_legend(ax, "upper left", bbox_to_anchor=(1, 1))

# %% [markdown]
# #correlation

# %%
train.corr()
# Out:
# <ipython-input-81-0bc27f030cd9>:1: FutureWarning: The default value of numeric_only in DataFrame.corr is deprecated. In a future version, it will default to False. Select only valid columns or specify the value of numeric_only to silence this warning.
#   train.corr()
#                     longitude  latitude  housing_median_age  total_rooms  \
# longitude            1.000000 -0.925744           -0.103618     0.041015
# latitude            -0.925744  1.000000            0.006480    -0.032324
# housing_median_age  -0.103618  0.006480            1.000000    -0.361585
# total_rooms          0.041015 -0.032324           -0.361585     1.000000
# total_bedrooms       0.066820 -0.064705           -0.320116     0.929260
# population           0.096875 -0.106290           -0.291642     0.854717
# households           0.052258 -0.068554           -0.302235     0.917051
# median_income       -0.020808 -0.072867           -0.122442     0.200334
# ...

# %% [markdown]
# اگر بخواهیم فقط برای متغیر هدف یا y را بسنحیم

# %%
train.corr()["median_house_value"]
# Out:
# <ipython-input-82-58701e32a644>:1: FutureWarning: The default value of numeric_only in DataFrame.corr is deprecated. In a future version, it will default to False. Select only valid columns or specify the value of numeric_only to silence this warning.
#   train.corr()["median_house_value"]
# longitude            -0.051167
# latitude             -0.137691
# housing_median_age    0.105329
# total_rooms           0.138007
# total_bedrooms        0.052814
# population           -0.021544
# households            0.070014
# median_income         0.686865
# median_house_value    1.000000
# identifier            0.064982
# Name: median_house_value, dtype: float64

# %% [markdown]
# برای ترسیم نمودار همبستگی متغیر هدف با فیچرها

# %%
sns.scatterplot(data= train,
                x="median_income",
                y="median_house_value",
                alpha= 0.2)
# Out:
# <Axes: xlabel='median_income', ylabel='median_house_value'>

# %%
ax= sns.scatterplot(data= train,
                x="median_income",
                y="median_house_value",
                alpha= 0.2,
                size= "population")
sns.move_legend(ax, "upper left", bbox_to_anchor=(1, 1))

# %% [markdown]
# #Attribute combinations (ترکیب فیچرها)

# %%
train["rooms_per_house"]= train["total_rooms"]/train["households"]
train["bedrooms_ratio"]=train["total_bedrooms"]/train["total_rooms"]
train["people_per_house"]=train["population"]/train["households"]
train
# Out:
#        longitude  latitude  housing_median_age  total_rooms  total_bedrooms  \
# 16415    -121.26     37.88                42.0        465.0            93.0
# 1279     -121.64     37.85                22.0       1999.0           415.0
# 7741     -118.15     33.95                35.0       2753.0           702.0
# 4425     -118.24     34.07                27.0        223.0            80.0
# 1283     -121.82     38.02                46.0        176.0            43.0
# ...          ...       ...                 ...          ...             ...
# 1221     -120.65     38.28                21.0       3095.0           681.0
# 12640    -121.45     38.53                34.0       1893.0           415.0
# 5747     -118.27     34.17                48.0       1560.0           280.0
# 16224    -121.33     37.98                36.0       3113.0           576.0
# 8967     -118.40     34.00                37.0       1534.0           258.0
#
# ...

# %% [markdown]
# #prepare data

# %%
train_features =train.drop("median_house_value", axis=1)
train_target= ["median_house_value"]
df["median_house_value"]
train_features
# Out:
#        longitude  latitude  housing_median_age  total_rooms  total_bedrooms  \
# 16415    -121.26     37.88                42.0        465.0            93.0
# 1279     -121.64     37.85                22.0       1999.0           415.0
# 7741     -118.15     33.95                35.0       2753.0           702.0
# 4425     -118.24     34.07                27.0        223.0            80.0
# 1283     -121.82     38.02                46.0        176.0            43.0
# ...          ...       ...                 ...          ...             ...
# 1221     -120.65     38.28                21.0       3095.0           681.0
# 12640    -121.45     38.53                34.0       1893.0           415.0
# 5747     -118.27     34.17                48.0       1560.0           280.0
# 16224    -121.33     37.98                36.0       3113.0           576.0
# 8967     -118.40     34.00                37.0       1534.0           258.0
#
# ...

# %% [markdown]
# ## Data cleaning

# %% [markdown]
# اگر بخواهیم سطرهایی که میسینگ ولیو دارند را حذف کنیم.

# %%
train_features.dropna(subset=["total_bedrooms"])
# Out:
#        longitude  latitude  housing_median_age  total_rooms  total_bedrooms  \
# 16415    -121.26     37.88                42.0        465.0            93.0
# 1279     -121.64     37.85                22.0       1999.0           415.0
# 7741     -118.15     33.95                35.0       2753.0           702.0
# 4425     -118.24     34.07                27.0        223.0            80.0
# 1283     -121.82     38.02                46.0        176.0            43.0
# ...          ...       ...                 ...          ...             ...
# 1221     -120.65     38.28                21.0       3095.0           681.0
# 12640    -121.45     38.53                34.0       1893.0           415.0
# 5747     -118.27     34.17                48.0       1560.0           280.0
# 16224    -121.33     37.98                36.0       3113.0           576.0
# 8967     -118.40     34.00                37.0       1534.0           258.0
#
# ...

# %%
train_features.dropna(subset=["total_bedrooms"]).info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 16344 entries, 16415 to 8967
# Data columns (total 13 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   longitude           16344 non-null  float64
#  1   latitude            16344 non-null  float64
#  2   housing_median_age  16344 non-null  float64
#  3   total_rooms         16344 non-null  float64
#  4   total_bedrooms      16344 non-null  float64
#  5   population          16344 non-null  float64
#  6   households          16344 non-null  float64
#  7   median_income       16344 non-null  float64
#  8   ocean_proximity     16344 non-null  object
#  9   identifier          16344 non-null  float64
#  10  rooms_per_house     16344 non-null  float64
#  11  bedrooms_ratio      16344 non-null  float64
#  12  people_per_house    16344 non-null  float64
# dtypes: float64(12), object(1)
# memory usage: 1.7+ MB

# %% [markdown]
# اگر دوباره تابع رافراخوانی کنیم باز هم با کل داده های مفقودی نمایش داا می شود. برای حل این مشکل کد های زیر زده می شوند.

# %%
train_featuresWithoutNA = train_features.dropna(subset=["total_bedrooms"])
train_features_withoutNA
# Out:
#        longitude  latitude  housing_median_age  total_rooms  total_bedrooms  \
# 16415    -121.26     37.88                42.0        465.0            93.0
# 1279     -121.64     37.85                22.0       1999.0           415.0
# 7741     -118.15     33.95                35.0       2753.0           702.0
# 4425     -118.24     34.07                27.0        223.0            80.0
# 1283     -121.82     38.02                46.0        176.0            43.0
# ...          ...       ...                 ...          ...             ...
# 1221     -120.65     38.28                21.0       3095.0           681.0
# 12640    -121.45     38.53                34.0       1893.0           415.0
# 5747     -118.27     34.17                48.0       1560.0           280.0
# 16224    -121.33     37.98                36.0       3113.0           576.0
# 8967     -118.40     34.00                37.0       1534.0           258.0
#
# ...
