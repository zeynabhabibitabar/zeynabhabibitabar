# %% [markdown]
# <a href="https://colab.research.google.com/github/zeynabhabibitabar/zeynabhabibitabar/blob/main/plot.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
pip install matplotlib

# %%
import matplotlib.pyplot as plt

# %%
import numpy as np
x= np.arange(-5,6)
n = int(input(f'enter the number:'))
y= x**n
plt.plot(x,y)
plt.show()
# Out:
# enter the number:8
